# %% [markdown]
# <a href="https://colab.research.google.com/github/PassionChicken-Leesuin/Standalone-DeepLearning/blob/master/Lec3/Lab4_write_pretty_DL_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.__version__)
# Out:
# 2.9.0+cu126

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import argparse
import numpy as np

# %% [markdown]
# ## Data Preparation

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainset, valset = torch.utils.data.random_split(trainset, [40000, 10000])
testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)


trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
                                          shuffle=True, num_workers=2)
valloader = torch.utils.data.DataLoader(valset, batch_size=4,
                                        shuffle=False)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# 100%|██████████| 170M/170M [00:03<00:00, 43.0MB/s]

# %% [markdown]
# ## Model Architecture

# %%
class MLP(nn.Module):
    def __init__(self, in_dim, out_dim, hid_dim, n_layer, act):
        super(MLP, self).__init__()
        self.in_dim = in_dim
        self.out_dim = out_dim
        self.hid_dim = hid_dim
        self.n_layer = n_layer
        self.act = act

        self.fc = nn.Linear(self.in_dim, self.hid_dim)
        self.linears = nn.ModuleList()

        for i in range(self.n_layer-1):
            self.linears.append(nn.Linear(self.hid_dim, self.hid_dim))
        self.fc2 = nn.Linear(self.hid_dim, self.out_dim)

        if self.act == 'relu':
            self.act = nn.ReLU()

    def forward(self, x):
        x = self.act(self.fc(x))
        for fc in self.linears:
            x = self.act(fc(x))
        x = self.fc2(x)
        return x

net = MLP(3072, 10, 100, 4, 'relu')

# %% [markdown]
# ## Define Experiment

# %%
#숫자가 없어야한다. 다 ars. 어쩌구로.. 하이퍼파라미팅 튜닝 용이하게!!

def experiment(args):

    net = MLP(args.in_dim, args.out_dim, args.hid_dim, args.n_layer, args.act)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    net = net.to(device)
    print(net)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=args.lr, momentum=args.mm)

    for epoch in range(args.epoch):  # loop over the dataset multiple times

        # ==== Train ===== #
        net.train()

        running_loss = 0.0
        train_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            optimizer.zero_grad() # [21.01.05 오류 수정] 매 Epoch 마다 .zero_grad()가 실행되는 것을 매 iteration 마다 실행되도록 수정했습니다.

            # get the inputs
            inputs, labels = data
            inputs = inputs.view(-1, 3072)

            inputs = inputs.to(device)
            labels = labels.to(device)

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            train_loss += loss.item()
            if i % 2000 == 1999:    # print every 2000 mini-batches
                print('[%d, %5d] loss: %.3f' %
                      (epoch + 1, i + 1, running_loss / 2000))
                running_loss = 0.0


        # ==== Validation ====== #
        net.eval()
        # optimizer.zero_grad() [21.01.05 코드 클린업] 아래 torch.no_grad()가 호출되고 Validation 과정에서는 Optimizer를 사용하지 않으므로 굳이 호출될 필요가 없습니다.

        correct = 0
        total = 0
        val_loss = 0
        with torch.no_grad(): # validation에서는 이거 꼭 써야함. gradient계산 완전히 비활성화. -> 메모리 절약
            for data in valloader: #validation 용 데이터 로더
                images, labels = data
                images = images.view(-1, 3072) #MLP 입력을 위해 Flatten
                images = images.to(device) #gpu이동
                labels = labels.to(device)
                outputs = net(images)

                loss = criterion(outputs, labels)
                val_loss += loss.item()

                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

            val_loss = val_loss / len(valloader)
            val_acc = 100 * correct / total

        print('Epoch {}, Train Loss: {}, Val Loss: {}, Val Acc: {}'.format(epoch, train_loss, val_loss, val_acc ))


    # ===== Evaluation ===== #
    net.eval()
    # optimizer.zero_grad() [21.01.05 코드 클린업] 아래 torch.no_grad()가 호출되고 Evaluation 과정에서는 Optimizer를 사용하지 않으므로 굳이 호출될 필요가 없습니다.

    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images = images.view(-1, 3072)
            images = images.to(device)
            labels = labels.to(device)

            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1) #각 샘플마다 가장 높은 점수(logit)를 가진 클래스 선택
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        test_acc = 100 * correct / total

    return train_loss, val_loss, val_acc, test_acc

# %% [markdown]
# ## Experiment

# %%
seed = 123
np.random.seed(seed)
torch.manual_seed(seed)

parser = argparse.ArgumentParser()
args = parser.parse_args("")


args.n_layer = 5
args.in_dim = 3072
args.out_dim = 10
args.hid_dim = 100
args.act = 'relu'

args.lr = 0.001
args.mm = 0.9
args.epoch = 2


list_var1 = [4, 5, 6]
list_var2 = [50, 100, 150]

for var1 in list_var1: #실험 총 경우의 수는 3*3=9번이겠네
    for var2 in list_var2:
        args.n_layer = var1
        args.hid_dim = var2
        result = experiment(args)
        print(result)
# Out:
# MLP(
#   (fc): Linear(in_features=3072, out_features=50, bias=True)
#   (linears): ModuleList(
#     (0-2): 3 x Linear(in_features=50, out_features=50, bias=True)
#   )
#   (fc2): Linear(in_features=50, out_features=10, bias=True)
#   (act): ReLU()
# )
# [1,  2000] loss: 2.191
# [1,  4000] loss: 1.886
# [1,  6000] loss: 1.789
# [1,  8000] loss: 1.716
# [1, 10000] loss: 1.704
# Epoch 0, Train Loss: 18572.689367175102, Val Loss: 1.6745559147596358, Val Acc: 39.94
# [2,  2000] loss: 1.646
# [2,  4000] loss: 1.621
# [2,  6000] loss: 1.578
# [2,  8000] loss: 1.590
# [2, 10000] loss: 1.566
# Epoch 1, Train Loss: 16001.582978576422, Val Loss: 1.5694481772899627, Val Acc: 44.27
# (16001.582978576422, 1.5694481772899627, 44.27, 45.25)
# MLP(
#   (fc): Linear(in_features=3072, out_features=100, bias=True)
#   (linears): ModuleList(
#     (0-2): 3 x Linear(in_features=100, out_features=100, bias=True)
#   )
#   (fc2): Linear(in_features=100, out_features=10, bias=True)
#   (act): ReLU()
# )
# [1,  2000] loss: 2.203
# [1,  4000] loss: 1.901
# [1,  6000] loss: 1.783
# [1,  8000] loss: 1.712
# [1, 10000] loss: 1.668
# Epoch 0, Train Loss: 18534.656148433685, Val Loss: 1.66577427110672, Val Acc: 40.68
# [2,  2000] loss: 1.609
# [2,  4000] loss: 1.582
# [2,  6000] loss: 1.543
# [2,  8000] loss: 1.538
# [2, 10000] loss: 1.513
# Epoch 1, Train Loss: 15570.414178669453, Val Loss: 1.5101860346496105, Val Acc: 46.71
# (15570.414178669453, 1.5101860346496105, 46.71, 47.36)
# MLP(
#   (fc): Linear(in_features=3072, out_features=150, bias=True)
#   (linears): ModuleList(
#     (0-2): 3 x Linear(in_features=150, out_features=150, bias=True)
#   )
#   (fc2): Linear(in_features=150, out_features=10, bias=True)
#   (act): ReLU()
# )
# [1,  2000] loss: 2.207
# [1,  4000] loss: 1.894
# [1,  6000] loss: 1.746
# [1,  8000] loss: 1.705
# [1, 10000] loss: 1.644
# Epoch 0, Train Loss: 18389.855708390474, Val Loss: 1.620159576356411, Val Acc: 42.36
# [2,  2000] loss: 1.579
# [2,  4000] loss: 1.563
# [2,  6000] loss: 1.515
# [2,  8000] loss: 1.507
# [2, 10000] loss: 1.488
# Epoch 1, Train Loss: 15304.406030982733, Val Loss: 1.4934669391989708, Val Acc: 47.38
# (15304.406030982733, 1.4934669391989708, 47.38, 47.49)
# MLP(
#   (fc): Linear(in_features=3072, out_features=50, bias=True)
#   (linears): ModuleList(
#     (0-3): 4 x Linear(in_features=50, out_features=50, bias=True)
#   )
#   (fc2): Linear(in_features=50, out_features=10, bias=True)
#   (act): ReLU()
# )
# [1,  2000] loss: 2.287
# [1,  4000] loss: 2.071
# [1,  6000] loss: 1.907
# [1,  8000] loss: 1.821
# [1, 10000] loss: 1.749
# Epoch 0, Train Loss: 19669.36663633585, Val Loss: 1.7136845468997954, Val Acc: 37.49
# [2,  2000] loss: 1.682
# [2,  4000] loss: 1.651
# [2,  6000] loss: 1.636
# [2,  8000] loss: 1.621
# [2, 10000] loss: 1.605
# Epoch 1, Train Loss: 16390.733751565218, Val Loss: 1.5578459648013114, Val Acc: 44.42
# (16390.733751565218, 1.5578459648013114, 44.42, 44.69)
# MLP(
#   (fc): Linear(in_features=3072, out_features=100, bias=True)
#   (linears): ModuleList(
#     (0-3): 4 x Linear(in_features=100, out_features=100, bias=True)
#   )
#   (fc2): Linear(in_features=100, out_features=10, bias=True)
#   (act): ReLU()
# )
# [1,  2000] loss: 2.298
# [1,  4000] loss: 2.069
# [1,  6000] loss: 1.927
# [1,  8000] loss: 1.824
# [1, 10000] loss: 1.757
# Epoch 0, Train Loss: 19749.957078754902, Val Loss: 1.7376720029592514, Val Acc: 35.97
# [2,  2000] loss: 1.679
# [2,  4000] loss: 1.637
# [2,  6000] loss: 1.605
# [2,  8000] loss: 1.583
# [2, 10000] loss: 1.558
# Epoch 1, Train Loss: 16124.096926257014, Val Loss: 1.5589846636831761, Val Acc: 43.85
# (16124.096926257014, 1.5589846636831761, 43.85, 44.76)
# MLP(
#   (fc): Linear(in_features=3072, out_features=150, bias=True)
#   (linears): ModuleList(
#     (0-3): 4 x Linear(in_features=150, out_features=150, bias=True)
#   )
#   (fc2): Linear(in_features=150, out_features=10, bias=True)
#   (act): ReLU()
# )
# [1,  2000] loss: 2.293
# [1,  4000] loss: 2.058
# [1,  6000] loss: 1.899
# [1,  8000] loss: 1.831
# [1, 10000] loss: 1.740
# Epoch 0, Train Loss: 19643.09373486042, Val Loss: 1.6903488707780838, Val Acc: 38.27
# [2,  2000] loss: 1.662
# [2,  4000] loss: 1.622
# [2,  6000] loss: 1.606
# [2,  8000] loss: 1.585
# [2, 10000] loss: 1.541
# Epoch 1, Train Loss: 16031.755441963673, Val Loss: 1.5531962972640991, Val Acc: 44.17
# (16031.755441963673, 1.5531962972640991, 44.17, 44.46)
# MLP(
#   (fc): Linear(in_features=3072, out_features=50, bias=True)
#   (linears): ModuleList(
#     (0-4): 5 x Linear(in_features=50, out_features=50, bias=True)
#   )
#   (fc2): Linear(in_features=50, out_features=10, bias=True)
#   (act): ReLU()
# )
# [1,  2000] loss: 2.303
# [1,  4000] loss: 2.280
# [1,  6000] loss: 2.082
# [1,  8000] loss: 1.976
# [1, 10000] loss: 1.894
# Epoch 0, Train Loss: 21071.520213484764, Val Loss: 1.8911363446474074, Val Acc: 29.67
# [2,  2000] loss: 1.848
# [2,  4000] loss: 1.814
# [2,  6000] loss: 1.784
# [2,  8000] loss: 1.753
# [2, 10000] loss: 1.734
# Epoch 1, Train Loss: 17866.27991962433, Val Loss: 1.7298845017910003, Val Acc: 34.7
# (17866.27991962433, 1.7298845017910003, 34.7, 35.52)
# MLP(
#   (fc): Linear(in_features=3072, out_features=100, bias=True)
#   (linears): ModuleList(
#     (0-4): 5 x Linear(in_features=100, out_features=100, bias=True)
#   )
#   (fc2): Linear(in_features=100, out_features=10, bias=True)
#   (act): ReLU()
# )
# [1,  2000] loss: 2.303
# [1,  4000] loss: 2.300
# [1,  6000] loss: 2.209
# [1,  8000] loss: 2.021
# [1, 10000] loss: 1.898
# Epoch 0, Train Loss: 21462.488828599453, Val Loss: 1.8835917319536208, Val Acc: 30.68
# [2,  2000] loss: 1.835
# [2,  4000] loss: 1.768
# [2,  6000] loss: 1.729
# [2,  8000] loss: 1.661
# [2, 10000] loss: 1.651
# Epoch 1, Train Loss: 17287.4644254148, Val Loss: 1.6553276089072229, Val Acc: 40.03
# (17287.4644254148, 1.6553276089072229, 40.03, 41.48)
# MLP(
#   (fc): Linear(in_features=3072, out_features=150, bias=True)
#   (linears): ModuleList(
#     (0-4): 5 x Linear(in_features=150, out_features=150, bias=True)
#   )
#   (fc2): Linear(in_features=150, out_features=10, bias=True)
#   (act): ReLU()
# )
# [1,  2000] loss: 2.303
# [1,  4000] loss: 2.278
# [1,  6000] loss: 2.072
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-666206131.py in <cell line: 0>()
#      25         args.n_layer = var1
#      26         args.hid_dim = var2
# ---> 27         result = experiment(args)
#      28         print(result)
#
# /tmp/ipython-input-3247802686.py in experiment(args)
#      18         running_loss = 0.0
#      19         train_loss = 0.0
# ---> 20         for i, data in enumerate(trainloader, 0):
#      21             optimizer.zero_grad() # [21.01.05 오류 수정] 매 Epoch 마다 .zero_grad()가 실행되는 것을 매 iteration 마다 실행되도록 수정했습니다.
#      22
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     730                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731                 self._reset()  # type: ignore[call-arg]
# --> 732             data = self._next_data()
#     733             self._num_yielded += 1
#     734             if (
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1480
#    1481             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1482             idx, data = self._get_data()
#    1483             self._tasks_outstanding -= 1
#    1484             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1442         else:
#    1443             while True:
# -> 1444                 success, data = self._try_get_data()
#    1445                 if success:
#    1446                     return data
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1273         #   (bool: whether successfully get data, any: data if successful else None)
#    1274         try:
# -> 1275             data = self._data_queue.get(timeout=timeout)
#    1276             return (True, data)
#    1277         except Exception as e:
#
# /usr/lib/python3.12/multiprocessing/queues.py in get(self, block, timeout)
#     120                 self._rlock.release()
#     121         # unserialize the data after having released the lock
# --> 122         return _ForkingPickler.loads(res)
#     123
#     124     def qsize(self):
#
# /usr/local/lib/python3.12/dist-packages/torch/multiprocessing/reductions.py in rebuild_storage_fd(cls, df, size)
#     539
#     540 def rebuild_storage_fd(cls, df, size):
# --> 541     fd = df.detach()
#     542     try:
#     543         storage = storage_from_cache(cls, fd_id(fd))
#
# /usr/lib/python3.12/multiprocessing/resource_sharer.py in detach(self)
#      55         def detach(self):
#      56             '''Get the fd.  This should only be called once.'''
# ---> 57             with _resource_sharer.get_connection(self._id) as conn:
#      58                 return reduction.recv_handle(conn)
#      59
#
# /usr/lib/python3.12/multiprocessing/resource_sharer.py in get_connection(ident)
#      84         from .connection import Client
#      85         address, key = ident
# ---> 86         c = Client(address, authkey=process.current_process().authkey)
#      87         c.send((key, os.getpid()))
#      88         return c
#
# /usr/lib/python3.12/multiprocessing/connection.py in Client(address, family, authkey)
#     523
#     524     if authkey is not None:
# --> 525         answer_challenge(c, authkey)
#     526         deliver_challenge(c, authkey)
#     527
#
# /usr/lib/python3.12/multiprocessing/connection.py in answer_challenge(connection, authkey)
#     951         raise ValueError(
#     952             "Authkey must be bytes, not {0!s}".format(type(authkey)))
# --> 953     message = connection.recv_bytes(256)         # reject large message
#     954     if not message.startswith(_CHALLENGE):
#     955         raise AuthenticationError(
#
# /usr/lib/python3.12/multiprocessing/connection.py in recv_bytes(self, maxlength)
#     214         if maxlength is not None and maxlength < 0:
#     215             raise ValueError("negative maxlength")
# --> 216         buf = self._recv_bytes(maxlength)
#     217         if buf is None:
#     218             self._bad_message_length()
#
# /usr/lib/python3.12/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     428
#     429     def _recv_bytes(self, maxsize=None):
# --> 430         buf = self._recv(4)
#     431         size, = struct.unpack("!i", buf.getvalue())
#     432         if size == -1:
#
# /usr/lib/python3.12/multiprocessing/connection.py in _recv(self, size, read)
#     393         remaining = size
#     394         while remaining > 0:
# --> 395             chunk = read(handle, remaining)
#     396             n = len(chunk)
#     397             if n == 0:
#
# KeyboardInterrupt:
